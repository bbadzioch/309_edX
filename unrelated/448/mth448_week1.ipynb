# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib notebook

# %%
img = plt.imread("green_screen.jpg")
plt.figure(figsize = (8, 8))
plt.imshow(img)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
imgc = img.copy()
img2 = abs(img  - np.array([127, 182,  89])).sum(axis=2)
img3 = abs(img  - np.array([ 82, 136,  50])).sum(axis=2)
img4 = abs(img  - np.array([38, 64, 17])).sum(axis=2)
imgc[(img2 <80) | (img3 <80) |  (img4 < 40)] = 255
plt.figure(figsize = (8, 8))
plt.imshow(imgc)
plt.show()

# %%
import cv2
def show_img(img):
    plt.figure(figsize = (8, 8))
    imgc = img[:, :, [2, 1, 0]]
    plt.imshow(imgc)
    plt.show()

# %%
imgc = img.copy()
img2 = img[:, :, 1]/(img.sum(axis=2) + 0.01)
imgc[img2 > 0.38] = [0, 0, 100]
show_img(imgc)

# %%
img = cv2.imread("green_screen.jpg")
cv2.imwrite("foo.jpg", img)
# Out:
# True

# %%
img[::20, :, :] = [255, 100, 255]
show_img(img)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
import pandas as pd

# %%
df = pd.read_csv("some_words.csv")
df
# Out:
#             phrase
# 0             fast
# 1              rat
# 2           reward
# 3            light
# 4             bulb
# 5           singer
# 6           coffee
# 7             noon
# 8          cutlery
# 9       Chiang Mai
# 10         floored
# 11          freeze
# 12          drawer
# 13             bed
# 14          carrot
# 15            mice
# 16        Yosemite
# 17         rotator
# 18          circus
# 19          babies
# 20  leather jacket
# 21      hieroglyph

# %%
df["pointless"] = 0
df
# Out:
#             phrase  pointless
# 0             fast          0
# 1              rat          0
# 2           reward          0
# 3            light          0
# 4             bulb          0
# 5           singer          0
# 6           coffee          0
# 7             noon          0
# 8          cutlery          0
# 9       Chiang Mai          0
# 10         floored          0
# 11          freeze          0
# 12          drawer          0
# 13             bed          0
# 14          carrot          0
# 15            mice          0
# 16        Yosemite          0
# 17         rotator          0
# 18          circus          0
# 19          babies          0
# 20  leather jacket          0
# 21      hieroglyph          0

# %%
df["length"] = df["phrase"].map(len)

# %%
df["first capital"] = df["phrase"].map(lambda s : s[0] == s[0].upper())
df
# Out:
#             phrase  pointless  length  first capital
# 0             fast          0       4          False
# 1              rat          0       3          False
# 2           reward          0       6          False
# 3            light          0       5          False
# 4             bulb          0       4          False
# 5           singer          0       6          False
# 6           coffee          0       6          False
# 7             noon          0       4          False
# 8          cutlery          0       7          False
# 9       Chiang Mai          0      10           True
# 10         floored          0       7          False
# 11          freeze          0       6          False
# 12          drawer          0       6          False
# 13             bed          0       3          False
# 14          carrot          0       6          False
# 15            mice          0       4          False
# 16        Yosemite          0       8           True
# ...

# %%
df["vowels"] = df["phrase"].map(lambda s : len([x for x in s if x  in "aeiou"]))
df
# Out:
#             phrase  pointless  length  first capital  vowels
# 0             fast          0       4          False       1
# 1              rat          0       3          False       1
# 2           reward          0       6          False       2
# 3            light          0       5          False       1
# 4             bulb          0       4          False       1
# 5           singer          0       6          False       2
# 6           coffee          0       6          False       3
# 7             noon          0       4          False       2
# 8          cutlery          0       7          False       2
# 9       Chiang Mai          0      10           True       4
# 10         floored          0       7          False       3
# 11          freeze          0       6          False       3
# 12          drawer          0       6          False       2
# 13             bed          0       3          False       1
# ...

# %%
df["vowels_ratio"] = df["vowels"]/df["length"]
df
# Out:
#             phrase  pointless  length  first capital  vowels  vowels_ratio
# 0             fast          0       4          False       1      0.250000
# 1              rat          0       3          False       1      0.333333
# 2           reward          0       6          False       2      0.333333
# 3            light          0       5          False       1      0.200000
# 4             bulb          0       4          False       1      0.250000
# 5           singer          0       6          False       2      0.333333
# 6           coffee          0       6          False       3      0.500000
# 7             noon          0       4          False       2      0.500000
# 8          cutlery          0       7          False       2      0.285714
# 9       Chiang Mai          0      10           True       4      0.400000
# 10         floored          0       7          False       3      0.428571
# ...

# %%
df["reversal"] = df["phrase"].map(lambda s : s[::-1])
df
# Out:
#             phrase  pointless  length  first capital  vowels  vowels_ratio  \
# 0             fast          0       4          False       1      0.250000
# 1              rat          0       3          False       1      0.333333
# 2           reward          0       6          False       2      0.333333
# 3            light          0       5          False       1      0.200000
# 4             bulb          0       4          False       1      0.250000
# 5           singer          0       6          False       2      0.333333
# 6           coffee          0       6          False       3      0.500000
# 7             noon          0       4          False       2      0.500000
# 8          cutlery          0       7          False       2      0.285714
# 9       Chiang Mai          0      10           True       4      0.400000
# 10         floored          0       7          False       3      0.428571
# ...

# %%
df["is_palindrome"] = (df["phrase"] == df["reversal"])
df
# Out:
#             phrase  pointless  length  first capital  vowels  vowels_ratio  \
# 0             fast          0       4          False       1      0.250000
# 1              rat          0       3          False       1      0.333333
# 2           reward          0       6          False       2      0.333333
# 3            light          0       5          False       1      0.200000
# 4             bulb          0       4          False       1      0.250000
# 5           singer          0       6          False       2      0.333333
# 6           coffee          0       6          False       3      0.500000
# 7             noon          0       4          False       2      0.500000
# 8          cutlery          0       7          False       2      0.285714
# 9       Chiang Mai          0      10           True       4      0.400000
# 10         floored          0       7          False       3      0.428571
# ...

# %%
df["sorted"] = df["phrase"].map(lambda s: "".join(sorted(s)))
df
# Out:
#             phrase  pointless  length  first capital  vowels  vowels_ratio  \
# 0             fast          0       4          False       1      0.250000
# 1              rat          0       3          False       1      0.333333
# 2           reward          0       6          False       2      0.333333
# 3            light          0       5          False       1      0.200000
# 4             bulb          0       4          False       1      0.250000
# 5           singer          0       6          False       2      0.333333
# 6           coffee          0       6          False       3      0.500000
# 7             noon          0       4          False       2      0.500000
# 8          cutlery          0       7          False       2      0.285714
# 9       Chiang Mai          0      10           True       4      0.400000
# 10         floored          0       7          False       3      0.428571
# ...

# %%
df["has_reversal"] = df["phrase"].map(lambda s: s in df["reversal"].values)
df
# Out:
#             phrase  pointless  length  first capital  vowels  vowels_ratio  \
# 0             fast          0       4          False       1      0.250000
# 1              rat          0       3          False       1      0.333333
# 2           reward          0       6          False       2      0.333333
# 3            light          0       5          False       1      0.200000
# 4             bulb          0       4          False       1      0.250000
# 5           singer          0       6          False       2      0.333333
# 6           coffee          0       6          False       3      0.500000
# 7             noon          0       4          False       2      0.500000
# 8          cutlery          0       7          False       2      0.285714
# 9       Chiang Mai          0      10           True       4      0.400000
# 10         floored          0       7          False       3      0.428571
# ...

# %%
"rotator" in df["phrase"].values
# Out:
# True

# %%
v
# Out:
# ['uu', 'aa', 'oo']

# %%
vv = []
for c in s:
    if c in "aeiou":
        vv.append(c)
vv
# Out:
# ['u', 'a', 'o']
