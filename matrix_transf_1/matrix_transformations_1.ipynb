# %% [markdown]
# # Matrix transformations 1

# %% [markdown]
# The code to produce html files with images for these problems:

# %%
from matrix_t import *
from math import *

d = {}
d["scale2.html"] = [[2, 0], [0, 2]]
d["ref_x.html"] = [[1, 0], [0, -1]]
d["ref_y.html"] = [[-1, 0], [0, 1]]
d["ref_orig.html"] = [[-1, 0], [0, -1]]
d["rot_plus90.html"] = [[0, -1], [1, 0]]
d["rot_minus45.html"] = [[cos(-pi/4), -sin(-pi/4)], [sin(-pi/4), cos(-pi/4)]]
d["skew1.html"] = [[1, -2], [0, 2]]
d["skew2.html"] = [[-4, -3], [4, -1]]

for h in d:
    x = house_transform_bk(d[h], left_shift = [0, 0])
    x.show_house(h)
    bk.output_file(h)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="13200">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="482ade4d-df87-48c4-a17a-6d96255e33f3"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="14581">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="48156131-fb28-4313-911f-cde630924b58"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="16006">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="30bab113-07fd-4991-8b97-19b63291643c"></div>
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
# ...

# %%
from matrix_t import *
from math import *

ML = [[-4, -3], [4, -1]]
MR = np.linalg.inv(np.array(ML))

x = house_transform_bk(ML=ML, MR=MR, left_shift = [0, 0])
x.show_house()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="18825">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="668951d6-cf4b-4508-8c98-39712220f73e"></div>
